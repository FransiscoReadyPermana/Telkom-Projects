# %% [markdown]
# # Objective 🎯🎯

# %% [markdown]
# We want to know, based on the data, which platform people mostly use to purchase products. Additionally, we would like to know which products should be promoted and also want to see which one is projected to have the highest sales in the future.

# %% [markdown]
# but first of all guys, pardon for my lazyness to translate the rest of the markdown below.

# %% [markdown]
# berikut adalah beberapa informasi yang saya dapatkan mengenai ketiga platform tersebut
#
# - ### WhatsApp (WA):
#     - Kecepatan dan Keterlibatan Tinggi: WhatsApp sering kali memiliki tingkat respons yang lebih tinggi daripada email atau SMS, karena pesan langsung masuk ke ponsel pelanggan dan dapat dibaca dengan cepat.
#     - Konten Kaya: Anda dapat mengirim gambar, video, tautan, dan pesan suara melalui WhatsApp, membuatnya cocok untuk berbagi informasi yang lebih kompleks atau visual.
#     - Komunikasi Interaktif: WhatsApp memungkinkan interaksi langsung seperti obrolan dua arah dan panggilan suara/video.
#     - Segmentasi Kontak: Anda dapat membuat daftar kontak berdasarkan kelompok atau segmen tertentu untuk mengirim pesan yang lebih tepat sasaran.
#
#     **Kelebihan:**
#     - Interaktif dan Langsung: WhatsApp memungkinkan Anda berinteraksi secara langsung dengan pelanggan dalam waktu nyata. Pesan dapat diterima dan dibalas dengan cepat.
#     - Personalisasi: Anda dapat mengirim pesan yang lebih personal kepada pelanggan Anda, menggunakan nama mereka dan memberikan layanan yang lebih khusus.
#     - Notifikasi Terbaca: Anda dapat melihat apakah pesan Anda telah dibaca, sehingga Anda tahu apakah pelanggan telah melihat pesan Anda.
#     - Media Kaya: Anda dapat mengirimkan gambar, video, tautan, dan dokumen secara langsung, yang bisa membantu dalam komunikasi yang lebih efektif.
#
#     **Kekurangan:**
#     - Dibutuhkan Nomor Telepon: Anda memerlukan nomor telepon pelanggan untuk menghubunginya melalui WhatsApp, yang mungkin tidak selalu tersedia atau diinginkan oleh pelanggan.
#     - Keterbatasan Pesan Massal: WhatsApp memiliki batasan dalam jumlah pesan yang dapat Anda kirimkan sekaligus, yang mungkin tidak efisien jika Anda ingin mencapai banyak pelanggan sekaligus.
#
#     **Siapa Targetnya?**
#
#     - Target Demografi: WhatsApp populer di kalangan pengguna ponsel pintar dari berbagai kelompok usia. Namun, pengguna muda cenderung lebih aktif dalam menggunakan platform ini.
#     - Tujuan Komunikasi: WhatsApp sering digunakan untuk interaksi langsung, dukungan pelanggan real-time, dan pesan-pesan pribadi antara teman dan keluarga.
#     - Bisnis yang Cocok: Bisnis yang ingin berkomunikasi secara langsung dengan pelanggan, memberikan dukungan pelanggan cepat, dan menawarkan promo eksklusif dapat memanfaatkan WhatsApp. Contoh bisnis yang cocok adalah restoran yang menerima pesanan melalui pesan WhatsApp atau toko e-commerce yang memberikan notifikasi pesanan.
#
# ---
#
# - ### Email:
#     - Fleksibilitas Desain: Email memungkinkan untuk mendesain pesan yang lebih rumit dan menarik dengan grafik, tata letak, dan format yang kaya.
#     - Keterbacaan: Email cenderung memiliki tingkat pembacaan yang lebih lambat daripada WhatsApp, tetapi memiliki kecenderungan untuk menyampaikan pesan yang lebih formal dan berwibawa.
#     - Segmentasi dan Automasi: Anda dapat menggunakan alat pemasaran email untuk mengirim pesan otomatis kepada pelanggan berdasarkan tindakan atau preferensi mereka.
#
#     **Kelebihan:**
#     - Format Fleksibel: Email memungkinkan Anda untuk mengirim pesan dalam format yang lebih kaya, termasuk gambar, video, dan tautan.
#     - Targeting yang Lebih Baik: Anda dapat dengan mudah mengirim email kepada kelompok pelanggan yang sudah ditargetkan, misalnya, berdasarkan preferensi atau perilaku mereka.
#     - Arsip dan Penyimpanan: Email memberikan kemampuan untuk menyimpan riwayat komunikasi dengan pelanggan dalam bentuk arsip yang mudah diakses.
#
#     **Kekurangan:**
#     - Tingkat Keterbacaan yang Rendah: Banyak email masuk ke folder spam atau promosi, dan tingkat keterbacaan email bisa lebih rendah dibandingkan dengan SMS atau WhatsApp.
#     - Tidak Secepat WA atau SMS: Email mungkin tidak sesegera WhatsApp atau SMS dalam hal interaksi real-time.
#
#     **siapa targetnya?**
#     - Target Demografi: Email umumnya digunakan oleh semua kelompok usia, tetapi tingkat penggunaan dapat bervariasi. Pengguna yang lebih muda mungkin lebih cenderung menggunakan email untuk komunikasi kerja atau akademis.
#     - Tujuan Komunikasi: Email sangat baik untuk mengirimkan informasi rinci, promosi, buletin, dan konten berbasis teks atau visual yang lebih kaya.
#     - Bisnis yang Cocok: Email cocok untuk bisnis yang ingin menyampaikan pesan yang lebih mendalam, mengirimkan konten edukatif, atau mengelola langganan pelanggan. Misalnya, perusahaan teknologi yang ingin mengirim buletin bulanan atau toko mode yang ingin mengumumkan koleksi terbaru.
#
# ---
#
# - ### SMS:
#
#     - Notifikasi Penting: SMS biasanya lebih efektif untuk mengirimkan pemberitahuan atau informasi penting secara singkat dan langsung.
#     - Dekat dengan Pelanggan: Karena pesan SMS hampir selalu dibaca dalam waktu singkat, ini cocok untuk berkomunikasi dengan cepat tentang penawaran terbatas atau peristiwa mendesak.
#     - Batasan Panjang Pesan: Pesan SMS terbatas pada 160 karakter, yang bisa menjadi tantangan jika Anda perlu menyampaikan informasi yang lebih rinci.
#
#     **kelebihan:**
#     - Dapat Diakses Tanpa Internet: SMS tidak memerlukan koneksi internet, sehingga bisa diakses oleh pelanggan di mana saja, bahkan jika mereka berada di daerah dengan koneksi internet yang buruk.
#     - Tingkat Keterbacaan Tinggi: SMS cenderung memiliki tingkat keterbacaan yang tinggi, karena pesan masuk langsung ke kotak masuk pelanggan.
#     - Sederhana dan Tidak Mengganggu: SMS adalah metode komunikasi yang sederhana dan tidak mengganggu, sehingga pelanggan mungkin lebih cenderung membacanya.
#
#     **Kekurangan:**
#     - Pesan Teks Terbatas: SMS memiliki batasan panjang pesan, yang bisa membuat sulit untuk menyampaikan pesan yang panjang atau kompleks.
#     - Kurang Interaktif: SMS tidak seinteraktif WhatsApp, dan Anda tidak dapat mengirim media kaya seperti gambar atau video.
#
#     **siapa targetnya?**
#     - Target Demografi: SMS cocok untuk semua kelompok usia dan hampir semua pengguna ponsel. Ini adalah salah satu metode komunikasi paling luas yang tersedia.
#     - Tujuan Komunikasi: SMS cocok untuk mengirimkan pemberitahuan, pengingat, penawaran khusus, atau pesan singkat yang perlu segera dilihat oleh pelanggan.
#     - Bisnis yang Cocok: Banyak bisnis menggunakan SMS untuk mengirimkan kode verifikasi, pengingat janji, dan penawaran khusus. Ini cocok untuk hampir semua jenis bisnis, termasuk e-commerce, pelayanan kesehatan, dan layanan pengiriman.

# %% [markdown]
# # Import Package

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

from jcopml.pipeline import num_pipe, cat_pipe
from jcopml.utils import save_model, load_model
from jcopml.plot import plot_missing_value
from jcopml.feature_importance import mean_score_decrease
import matplotlib.dates as mdates

import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, r2_score
import matplotlib.pyplot as plt

# %% [markdown]
# # Import Dataset

# %%
data = pd.read_csv("../../Data/Monthly Usage Masked .csv", parse_dates=['Timestamp'])
data.drop(columns=[f'Unnamed: {x}' for x in range(14, 20)] + ['Nama AM / Presales', 'Dokumen PO (isi dengan link)'], inplace=True)
data.fillna("kosong", inplace=True)
df = data.copy()
df
# Out:
#               Timestamp Nama Client/Perusahaan?                     Service 1  \
# 0   2022-01-21 12:59:57            Nama Klien 1                      WHATSAPP
# 1   2022-01-21 13:00:40            Nama Klien 1                      WHATSAPP
# 2   2022-01-25 14:25:23            Nama Klien 2                       Whatapp
# 3   2022-01-26 17:48:12            Nama Klien 3                     Whatsappp
# 4   2022-01-27 14:37:11            Nama Klien 4                Whatsapp B & I
# ..                  ...                     ...                           ...
# 269 2023-06-22 15:01:14          Nama Klien 225  Register - SMS Premium Lokal
# 270 2023-06-23 11:29:01          Nama Klien 226                   B - SMS LBA
# 271 2023-06-26 15:48:27          Nama Klien 227                   B - SMS LBA
# 272 2023-06-26 15:52:42          Nama Klien 228                   B - SMS LBA
# 273 2023-06-26 20:36:40          Nama Klien 229                   B - SMS LBA
#
# ...

# %% [markdown]
# ## Melihat statistik deskriptif dari data

# %%
df.describe()
# Out:
# C:\Users\Jayy\AppData\Local\Temp\ipykernel_10576\3627053830.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe()
#                   Timestamp Nama Client/Perusahaan?  \
# count                   274                     274
# unique                  274                     229
# top     2022-01-21 12:59:57           Nama Klien 64
# freq                      1                       5
# first   2022-01-21 12:59:57                     NaN
# last    2023-06-26 20:36:40                     NaN
#
#                                Service 1 Service 2 Service 3 Service 4  \
# count                                274       274       274       274
# unique                                46        40        30        20
# ...

# %%
df.columns = df.columns.astype(str)
df.dtypes
# Out:
# Timestamp                  datetime64[ns]
# Nama Client/Perusahaan?            object
# Service 1                          object
# Service 2                          object
# Service 3                          object
# Service 4                          object
# Service 5                          object
# Service 6                          object
# Service 7                          object
# Service 8                          object
# Service 9                          object
# Service 10                         object
# dtype: object

# %% [markdown]
# # Membuat kolom wa, sms, dan email
# nilai-nilai pada kolom tersebut saya dapatkan berdasarkan nilai wildcard.
#
# untuk kolom wa, saya membuat nilai wildcard dengan mencari apakah ada kata what pada service yang ada.
# pada kolom sms saya menggunakan nilai wildcard sms, dan pada kolom email saya menggunakan nilai wildcard email

# %%
service_columns = [f'Service {x}' for x in range(1, 11)]

df['wa'] = df[service_columns].apply(lambda row: int(any(row.str.contains('what', case=False))), axis=1)
df['sms'] = df[service_columns].apply(lambda row: int(any(row.str.contains('sms', case=False))), axis=1)
df['email'] = df[service_columns].apply(lambda row: int(any(row.str.contains('email', case=False))), axis=1)
df
# Out:
#               Timestamp Nama Client/Perusahaan?                     Service 1  \
# 0   2022-01-21 12:59:57            Nama Klien 1                      WHATSAPP
# 1   2022-01-21 13:00:40            Nama Klien 1                      WHATSAPP
# 2   2022-01-25 14:25:23            Nama Klien 2                       Whatapp
# 3   2022-01-26 17:48:12            Nama Klien 3                     Whatsappp
# 4   2022-01-27 14:37:11            Nama Klien 4                Whatsapp B & I
# ..                  ...                     ...                           ...
# 269 2023-06-22 15:01:14          Nama Klien 225  Register - SMS Premium Lokal
# 270 2023-06-23 11:29:01          Nama Klien 226                   B - SMS LBA
# 271 2023-06-26 15:48:27          Nama Klien 227                   B - SMS LBA
# 272 2023-06-26 15:52:42          Nama Klien 228                   B - SMS LBA
# 273 2023-06-26 20:36:40          Nama Klien 229                   B - SMS LBA
#
# ...

# %%
df.sms.value_counts(), df.email.value_counts(), df.wa.value_counts()
# Out:
# (0    169
#  1    105
#  Name: sms, dtype: int64,
#  0    243
#  1     31
#  Name: email, dtype: int64,
#  1    157
#  0    117
#  Name: wa, dtype: int64)

# %%
df
# Out:
#               Timestamp Nama Client/Perusahaan?                     Service 1  \
# 0   2022-01-21 12:59:57            Nama Klien 1                      WHATSAPP
# 1   2022-01-21 13:00:40            Nama Klien 1                      WHATSAPP
# 2   2022-01-25 14:25:23            Nama Klien 2                       Whatapp
# 3   2022-01-26 17:48:12            Nama Klien 3                     Whatsappp
# 4   2022-01-27 14:37:11            Nama Klien 4                Whatsapp B & I
# ..                  ...                     ...                           ...
# 269 2023-06-22 15:01:14          Nama Klien 225  Register - SMS Premium Lokal
# 270 2023-06-23 11:29:01          Nama Klien 226                   B - SMS LBA
# 271 2023-06-26 15:48:27          Nama Klien 227                   B - SMS LBA
# 272 2023-06-26 15:52:42          Nama Klien 228                   B - SMS LBA
# 273 2023-06-26 20:36:40          Nama Klien 229                   B - SMS LBA
#
# ...

# %% [markdown]
# setelah membuat ketiga kolom wa, email, dan sms. selanjutnya, saya menghapus kolom service karena kolom tersebut sudah tidak mengandung informasi apa-apa lagi. kemudian saya membuat kolom total yang nilainya berisi hasil penjumlahan dari kolom sms, wa, dan email

# %%
df.drop(columns=service_columns, inplace=True)
df.set_index("Timestamp", inplace=True)
df['total'] = df['sms'] + df['wa'] + df['email'] 
df
# Out:
#                     Nama Client/Perusahaan?  wa  sms  email  total
# Timestamp
# 2022-01-21 12:59:57            Nama Klien 1   1    0      0      1
# 2022-01-21 13:00:40            Nama Klien 1   1    0      0      1
# 2022-01-25 14:25:23            Nama Klien 2   1    0      0      1
# 2022-01-26 17:48:12            Nama Klien 3   1    0      0      1
# 2022-01-27 14:37:11            Nama Klien 4   1    1      1      3
# ...                                     ...  ..  ...    ...    ...
# 2023-06-22 15:01:14          Nama Klien 225   0    1      0      1
# 2023-06-23 11:29:01          Nama Klien 226   0    1      0      1
# 2023-06-26 15:48:27          Nama Klien 227   0    1      0      1
# 2023-06-26 15:52:42          Nama Klien 228   0    1      0      1
# 2023-06-26 20:36:40          Nama Klien 229   0    1      0      1
#
# [274 rows x 5 columns]

# %% [markdown]
# # Membuat timeseries
# untuk membuat data yang saya miliki menjadi timeseries, saya melakukan resample perbulan

# %%
timeseries = df.resample('M').sum()
timeseries
# Out:
# C:\Users\Jayy\AppData\Local\Temp\ipykernel_10576\1896794096.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   timeseries = df.resample('M').sum()
#             wa  sms  email  total
# Timestamp
# 2022-01-31   6    2      2     10
# 2022-02-28   5    1      0      6
# 2022-03-31   4    2      0      6
# 2022-04-30   4    0      1      5
# 2022-05-31   3    1      0      4
# 2022-06-30  10    2      3     15
# 2022-07-31   6    2      1      9
# 2022-08-31  11    5      6     22
# 2022-09-30  13   10      5     28
# 2022-10-31   9    7      2     18
# 2022-11-30   5    5      1     11
# 2022-12-31   7    4      2     13
# 2023-01-31  11    7      1     19
# 2023-02-28  25   18      3     46
# 2023-03-31  15    6      2     23
# 2023-04-30  10   12      0     22
# ...

# %% [markdown]
# ## Membuat plot

# %%
fig,ax = plt.subplots()
df.drop(columns='total').resample('M').sum().plot(figsize=(15, 5), ax=ax)

ax1 = ax.twinx()
df[['total']].resample('M').sum().plot(figsize=(15, 5), ax=ax1, color='red', alpha=0.5, legend=False, linestyle='--')
# Out:
# C:\Users\Jayy\AppData\Local\Temp\ipykernel_10576\2062096525.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.drop(columns='total').resample('M').sum().plot(figsize=(15, 5), ax=ax)
# <Axes: xlabel='Timestamp'>

# %% [markdown]
# kalo diliat dari plotnya yaa, peaknya itu ada di february 2023. yang paling low itu tuh email, yg mid itu sms, dan yang paling tinggi itu wa
#
# tapi tapi tapi kalo kita liatin yaa entah kenapa tuh walaupun di feb itu udh sampe peak nya, tp kok email tuh gaikut naik banget kyk gy lain
#
# trus juga email tuh dia punya fluktuasi yang beda sama yg lain. terutama pas mulai di bulan juni 2022. setelah disaat semua pada naik dia ga ikut naik. contohnya kyk yg di januari 2023, dan di maret 2023.

# %%
timeseries.columns.shape[0]
# Out:
# 4

# %% [markdown]
# ## Pembuatan Model LSTM
# Kemudian saya membuat model lstm buat coba prediksi 4 nilai itu (wa, email, sms, total)
#
# saya Menggunakan 8 sequence length, 1 forecast horizon, 64 jumlah neuron, dan 100 epoch

# %%
sequence_length = 8  # Length of the input sequence
forecast_horizon = 1  # Number of steps to forecast ahead


# Prepare data for training
X_train, y_train = [], []
for i in range(len(timeseries) - sequence_length - forecast_horizon + 1):
    X_train.append(timeseries[i:i+sequence_length])
    y_train.append(timeseries[i+sequence_length:i+sequence_length+forecast_horizon])
X_train = np.array(X_train)
y_train = np.array(y_train)

# Build the LSTM model
model = Sequential()
model.add(LSTM(64, activation='relu', input_shape=(sequence_length, timeseries.columns.shape[0]), return_sequences=False))
model.add(Dense(forecast_horizon * timeseries.columns.shape[0]))  # 4 outputs for 4 value columns

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=16, shuffle=True)

# Make predictions
new_data = timeseries.iloc[-sequence_length:].values
new_data = np.expand_dims(new_data, axis=0)
predictions = np.round(model.predict(new_data))

# Calculate metrics
actual_values = timeseries.iloc[-1].values
mse = mean_squared_error(actual_values, predictions[0])
mape = mean_absolute_percentage_error(actual_values, predictions[0])
r2 = r2_score(actual_values, predictions[0])

print("MSE:", mse)
print("MAPE:", mape)
print("R2:", r2)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 1s 837ms/step - loss: 186.7126
# Epoch 2/100
# 1/1 [==============================] - 0s 5ms/step - loss: 178.7929
# Epoch 3/100
# 1/1 [==============================] - 0s 5ms/step - loss: 171.0433
# Epoch 4/100
# 1/1 [==============================] - 0s 4ms/step - loss: 163.3112
# Epoch 5/100
# 1/1 [==============================] - 0s 4ms/step - loss: 155.4241
# Epoch 6/100
# 1/1 [==============================] - 0s 4ms/step - loss: 147.2703
# Epoch 7/100
# 1/1 [==============================] - 0s 6ms/step - loss: 138.7262
# Epoch 8/100
# 1/1 [==============================] - 0s 4ms/step - loss: 129.6979
# Epoch 9/100
# 1/1 [==============================] - 0s 5ms/step - loss: 120.1334
# Epoch 10/100
# 1/1 [==============================] - 0s 5ms/step - loss: 110.0937
# Epoch 11/100
# 1/1 [==============================] - 0s 4ms/step - loss: 99.8315
# Epoch 12/100
# ...

# %%
sequence_length, timeseries.columns.shape[0]
# Out:
# (8, 4)

# %%
sequence_length, timeseries.shape[1]
# Out:
# (8, 4)

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Reshape
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, r2_score

sequence_length = 8  # Panjang dari urutan input
forecast_horizon = 3  # Jumlah langkah yang akan diprediksi ke depan (2 atau 3)

# Menyiapkan data untuk pelatihan
X_train, y_train = [], []
for i in range(len(timeseries) - sequence_length - forecast_horizon + 1):
    X_train.append(timeseries[i:i+sequence_length])
    y_train.append(timeseries[i+sequence_length:i+sequence_length+forecast_horizon])
X_train = np.array(X_train)
y_train = np.array(y_train)

# Membangun model LSTM
model = Sequential()
model.add(LSTM(64, activation='relu', input_shape=(sequence_length, timeseries.shape[1]), return_sequences=False))
model.add(Dense(forecast_horizon * timeseries.shape[1]))  # Output layer sesuai dengan jumlah langkah yang ingin diprediksi
model.add(Reshape((forecast_horizon, timeseries.shape[1])))  # Reshape output to match the target shape

# %%
X_train.shape, y_train.shape
# Out:
# ((8, 8, 4), (8, 3, 4))

# %%
sequence_length, timeseries.shape[1]
# Out:
# (8, 4)

# %%
forecast_horizon * timeseries.shape[1]
# Out:
# 12

# %%
# Mengompilasi model
model.compile(optimizer='adam', loss='mean_squared_error')

# Melatih model
model.fit(X_train, y_train, epochs=100, batch_size=16, shuffle=True)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 1s 924ms/step - loss: 3.3110
# Epoch 2/100
# 1/1 [==============================] - 0s 4ms/step - loss: 15.7592
# Epoch 3/100
# 1/1 [==============================] - 0s 4ms/step - loss: 4.5234
# Epoch 4/100
# 1/1 [==============================] - 0s 6ms/step - loss: 11.3891
# Epoch 5/100
# 1/1 [==============================] - 0s 5ms/step - loss: 6.0712
# Epoch 6/100
# 1/1 [==============================] - 0s 5ms/step - loss: 4.1924
# Epoch 7/100
# 1/1 [==============================] - 0s 5ms/step - loss: 5.2861
# Epoch 8/100
# 1/1 [==============================] - 0s 4ms/step - loss: 6.0674
# Epoch 9/100
# 1/1 [==============================] - 0s 4ms/step - loss: 6.0880
# Epoch 10/100
# 1/1 [==============================] - 0s 5ms/step - loss: 5.4148
# Epoch 11/100
# 1/1 [==============================] - 0s 4ms/step - loss: 4.3293
# Epoch 12/100
# 1/1 [==============================] - 0s 4ms/step - loss: 3.5104
# ...

# %%
new_data = timeseries.iloc[-sequence_length:].values
new_data = np.expand_dims(new_data, axis=0)
predictions = model.predict(new_data)

# Menambahkan hasil prediksi ke dalam data timeseries
predicted_values = np.round(predictions[0])
predicted_values
# Out:
# 1/1 [==============================] - 0s 16ms/step
# array([[12.,  7.,  1., 25.],
#        [27., 26., -2., 52.],
#        [ 8.,  7., 10., 19.]], dtype=float32)

# %% [markdown]
# hasilnya cukup bagus juga ternyata 👍👍

# %%
pred_index = timeseries.index[-1] + pd.DateOffset(months=1)
pred = pd.DataFrame(predictions, columns=timeseries.columns, index=[pred_index])

# Append predictions to the original time series
timeseries = timeseries.append(pred)
timeseries
# Out:
# C:\Users\Jayy\AppData\Local\Temp\ipykernel_5008\184443465.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   timeseries = timeseries.append(pred)
#               wa   sms  email  total
# 2022-01-31   6.0   2.0    2.0   10.0
# 2022-02-28   5.0   1.0    0.0    6.0
# 2022-03-31   4.0   2.0    0.0    6.0
# 2022-04-30   4.0   0.0    1.0    5.0
# 2022-05-31   3.0   1.0    0.0    4.0
# 2022-06-30  10.0   2.0    3.0   15.0
# 2022-07-31   6.0   2.0    1.0    9.0
# 2022-08-31  11.0   5.0    6.0   22.0
# 2022-09-30  13.0  10.0    5.0   28.0
# 2022-10-31   9.0   7.0    2.0   18.0
# 2022-11-30   5.0   5.0    1.0   11.0
# 2022-12-31   7.0   4.0    2.0   13.0
# 2023-01-31  11.0   7.0    1.0   19.0
# 2023-02-28  25.0  18.0    3.0   46.0
# 2023-03-31  15.0   6.0    2.0   23.0
# 2023-04-30  10.0  12.0    0.0   22.0
# 2023-05-31   6.0  11.0    2.0   19.0
# 2023-06-30   7.0  10.0    0.0   17.0
# ...

# %% [markdown]
# saya memasukkan nilai hasil prediksi kedata. tujuannya adalah saya ingin melakukan prediksi untuk 2 periode kedepan

# %%
new_data = timeseries.iloc[-sequence_length:].values
new_data = np.expand_dims(new_data, axis=0)
predictions = np.round(model.predict(new_data))

# Calculate metrics
actual_values = timeseries.iloc[-1].values
mse = mean_squared_error(actual_values, predictions[0])
mape = mean_absolute_percentage_error(actual_values, predictions[0])
r2 = r2_score(actual_values, predictions[0])

print("MSE:", mse)
print("MAPE:", mape)
print("R2:", r2)
# Out:
# 1/1 [==============================] - 0s 122ms/step
# MSE: 0.25
# MAPE: 0.0125
# R2: 0.9940476190476191

# %% [markdown]
# melakukan prediksi untuk satu periode selanjutnya dan ternyata memang berdasarkan metrik r2, hasil perdiksinya bagus juga

# %%
pred_index = timeseries.index[-1] + pd.DateOffset(months=1)
pred = pd.DataFrame(predictions, columns=timeseries.columns, index=[pred_index])

# Append predictions to the original time series
timeseries = timeseries.append(pred)
timeseries
# Out:
# C:\Users\Jayy\AppData\Local\Temp\ipykernel_5008\184443465.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   timeseries = timeseries.append(pred)
#               wa   sms  email  total
# 2022-01-31   6.0   2.0    2.0   10.0
# 2022-02-28   5.0   1.0    0.0    6.0
# 2022-03-31   4.0   2.0    0.0    6.0
# 2022-04-30   4.0   0.0    1.0    5.0
# 2022-05-31   3.0   1.0    0.0    4.0
# 2022-06-30  10.0   2.0    3.0   15.0
# 2022-07-31   6.0   2.0    1.0    9.0
# 2022-08-31  11.0   5.0    6.0   22.0
# 2022-09-30  13.0  10.0    5.0   28.0
# 2022-10-31   9.0   7.0    2.0   18.0
# 2022-11-30   5.0   5.0    1.0   11.0
# 2022-12-31   7.0   4.0    2.0   13.0
# 2023-01-31  11.0   7.0    1.0   19.0
# 2023-02-28  25.0  18.0    3.0   46.0
# 2023-03-31  15.0   6.0    2.0   23.0
# 2023-04-30  10.0  12.0    0.0   22.0
# 2023-05-31   6.0  11.0    2.0   19.0
# 2023-06-30   7.0  10.0    0.0   17.0
# ...

# %% [markdown]
# memasukkan lagi hasil prediksi periode selanjutnya ke data untuk selanjutnya saya buat plot secara keseluruhan

# %%
fig,ax = plt.subplots()
timeseries.plot(figsize=(15, 5), ax=ax)
# Out:
# <Axes: >

# %% [markdown]
# # Melihat hasil prediksi dari model yang telah saya buat

# %% [markdown]
# ## #1 Run
# ![image.png](attachment:image.png)

# %% [markdown]
# ## #2 Run
# ![image.png](attachment:image.png)

# %% [markdown]
# ## #3 Run
# ![image.png](attachment:image.png)

# %% [markdown]
# # Kesimpulan

# %% [markdown]
# berdasarkan 3 kali running, model yang saya bangun menunjukan bahwa ada kecenderungan bahwa akan ada kenaikan pada platform wa, dan email. namun, penurunan pada platform sms. jadi disarankan kedepannya untuk fokus push promosi untuk platform wa. mengingat wa juga merupakan sebuah produk yang terlaris dibandingkan 2 produk pada platform lainnnya, dan juga platform ini memang platform yang favorit dan sangat direkomendasikan digunakan untuk berinteraksi dengan konsumen

# %% [markdown]
# disamping itu, kita juga tidak bisa menutup mata pada ketertarikan konsumen pada platform sms. walapun berdasarkan hasil prediksi model yang saya buat, platform sms cenderung turun, namun jika dilihat lagi berdasarkan data-data sebelumnya sms juga merupakan salah satu platform favorit para konsumen. mengingat mungkin sms cenderung lebih memiliki jangkauan yang lebih luas dibandingkan kedua platform lainnya karena pada platform ini tidak memerlukan internet untuk pesan bisa tersampai kepada konsumennya. jadi SMS juga bisa diberikan sedikit perhatian untuk terus di push

# %% [markdown]
# untuk Email, sepertinya platform ini terlalu segemented. sehingga customer juga tidak terlalu banyak yang memesan layanan ini. jadi untuk email sepertinya bisa untuk sedikit dikesampingkan. karena memang tingkat terbacanya yang rendah, dan juga tidak secepat sms dan juga wa
